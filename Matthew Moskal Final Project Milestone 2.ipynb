# %% [markdown]
# # Matthew Moskal Final Project Milestone 2
#
# ### Findings from my exploratory analysis of my dataset:
# #### My dataset has 773,165 rows and 22 columns. It includes vessel IDs, years, flags, vessel classes, vessel size measurements, engine power, tonnage, and activity hours. There are both numeric and text columns. Several columns have many missing values, particularly the registry-based fields, such as flag_registry, vessel_class_registry, length_m_registry, engine_power_kw_registry, and tonnage_gt_registry. The inferred and GFW versions of these fields are mostly complete. Most vessels fall in common ranges. Typical vessel lengths range from 19 to 29 meters, engine powers range from 300–480 kW, and tonnages are usually between approximately 50 and 180 GT, although some extreme outliers exist. Activity levels vary widely, with average active hours around 2,500 and average fishing hours around 900. The dataset contains multiple flag fields, which can help me answer questions I have about particular countries' fishing efforts. Many vessels appear multiple times because they show up in different years. Overall, the dataset is large, mixed-type, and contains missing data mainly in registry information.

# %%
import pandas as pd

# Loading my dataset
data = pd.read_csv("fishing-vessels-v3.csv", low_memory=False) #low_memory = False used to combat a warning against a mixed column type

print(data.describe())
print(data.columns)
print(data.shape)
print(data.dtypes)
print(data.head())
print(data.tail())
print(data.sample())
print(data.info())
# Out:
#                mmsi           year  vessel_class_inferred_score  \
# count  7.731650e+05  773165.000000                767445.000000
# mean   4.039303e+08    2019.520510                     0.789423
# std    1.581184e+08       3.355573                     0.164844
# min    4.100000e+01    2012.000000                     0.500000
# 25%    2.734373e+08    2017.000000                     0.640000
# 50%    4.124136e+08    2020.000000                     0.802000
# 75%    4.160004e+08    2022.000000                     0.953000
# max    1.073742e+09    2024.000000                     1.000000
#
#        length_m_inferred  length_m_registry   length_m_gfw  \
# count      767445.000000      204350.000000  772950.000000
# mean           25.859841          28.260790      25.458877
# std            10.771665          18.355861      11.531934
# min             6.421000           5.000000       5.000000
# 25%            19.372000          15.900000      18.900000
# ...
